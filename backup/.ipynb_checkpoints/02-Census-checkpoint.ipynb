# %%
DATA_PATH = "/data-restricted/home/cheick_ba/safe_datasets_on_nas/safe_datasets/raw/"#"/home/jupyter-cheick_ba/nas/data_on_nas/datasets/raw/"

# %%
from utils import *

# %% [markdown]
# # Run a census

# %%
datasets = {
    "karate": "./demofiles/preprocessed/karate/karate_edges.csv.gz",
    #"gn": "./demofiles/preprocessed/gn/gn.csv.gz",
    #"nft-test":
}

# %%
save_path = "demofiles/triadic_data/"
n_processes = 8

# %%
mega_results = {}
for selected_dataset in datasets:
    
    save_name = selected_dataset
    transaction_filepath = datasets[selected_dataset]

    # Construct the graph (networkx)
    G = build_graph(transaction_filepath, start_time = None, end_time = None)

    # Just a census
    results = census_functions.parallel_triadic_census_plain(G, save_name, 
                                                         folder=save_path, store_closed=True, n_processes=2)
    
    
    # A census + N time shuffled census runs
    #results = census_functions.parallel_triadic_census_shuffled(G, save_name, 
                                                            #shuffle_type="time", N=3, 
                                                            #folder=save_path, store_closed=True, n_processes=2)
    # A census + N structure shuffled census runs
    #results = census_functions.parallel_triadic_census_shuffled(G, save_name, 
                                                            #shuffle_type="structure", N=3, shuffle_nswapfraction=0.3,
                                                            #folder=save_path, store_closed=True, n_processes=2)
    
    # A census + N time and structure shuffled census runs
    #results = census_functions.parallel_triadic_census_shuffled(G, save_name, 
                                                            #shuffle_type="time_structure", N=3, shuffle_nswapfraction=0.3,
                                                            #folder=save_path, store_closed=True, n_processes=2)
    
    # Save original G --- not the best spot, but needed for enumeration
    #GRAPH_PATH = os.path.join(results["folder_exp"],"graph.lzma")
    #glib_storage.save_snapshot_lzma(G, GRAPH_PATH)   
    
    mega_results[save_name] = results
# Out:
#    from  to  timestamp
# 0    31  24 2017-11-01
# (156, 3)
# digraph <class 'networkx.classes.digraph.DiGraph'>
# 2017-11-29 00:00:00
#   0%|          | 0/147 [00:00<?, ?it/s]
# DiGraph with 34 nodes and 147 edges
# No shuffling function specified!!!
# 2023-09-13 14-48-49
# Creating: /data-restricted/home/cheick_ba/data_on_nas/archived/triadi_osnem/TemporalTriadDelay/demofiles/triadic_data/karate_2023-09-13 14-48-49
# /data-restricted/home/cheick_ba/data_on_nas/archived/triadi_osnem/TemporalTriadDelay/demofiles/triadic_data/karate_2023-09-13 14-48-49 e poi karate_main
# 2023-09-13 14:48:49.375279 Starting new_generate_snapshot
# Creating: /data-restricted/home/cheick_ba/data_on_nas/archived/triadi_osnem/TemporalTriadDelay/demofiles/triadic_data/karate_2023-09-13 14-48-49
# Folder: /data-restricted/home/cheick_ba/data_on_nas/archived/triadi_osnem/TemporalTriadDelay/demofiles/triadic_data/karate_2023-09-13 14-48-49 already exists, we are going on
#
# Creating: /data-restricted/home/cheick_ba/data_on_nas/archived/triadi_osnem/TemporalTriadDelay/demofiles/triadic_data/karate_2023-09-13 14-48-49/karate_main/
# 2023-09-13 14:48:49.379365 Starting make_mapping_user_id
# 2023-09-13 14:48:49.384621 Completed make_mapping_user_id in  0.0052111148834228516
# 2023-09-13 14:48:49.384944 Starting make_timestamp_map
# NOTE: timestamps will start from 1
# 2023-09-13 14:48:49.387512 Completed make_timestamp_map in  0.0023949146270751953
# timestamp limit was not defined, we use all data so limit is: 2017-11-28 00:00:00
#
# karate_main_2017-11-28 00:00:00
#
# 2023-09-13 14:48:49.388187 Starting generate_snapshot
# 2023-09-13 14:48:49.388261 t <=  2017-11-28 00:00:00
# 2023-09-13 14:48:49.390338 Snapshot till 2017-11-28 00:00:00 ord/size: 34 147
# 2023-09-13 14:48:49.390460 Completed generate_snapshot in  0.0022094249725341797
# 2023-09-13 14:48:49.390565 Starting preprocess_snapshot
# Successfully created the directory /data-restricted/home/cheick_ba/data_on_nas/archived/triadi_osnem/TemporalTriadDelay/demofiles/triadic_data/karate_2023-09-13 14-48-49/karate_main//karate_main_2017-11-28 00:00:00
# DiGraph with 34 nodes and 147 edges
# 2023-09-13 14:48:49.392457 Starting make_mapped_graph
# 2023-09-13 14:48:49.395927 Completed make_mapped_graph in  0.003418445587158203
# 2023-09-13 14:48:49.396228 Starting get_neighborhoods
# 2023-09-13 14:48:49.399241 Completed get_neighborhoods in  0.002840280532836914
# 2023-09-13 14:48:49.399951 Starting calc_pagerank_elite
# 2023-09-13 14:48:49.407167 Completed calc_pagerank_elite in  0.007158517837524414
# 2023-09-13 14:48:49.407308 Starting calc_outdegree_elite
# 2023-09-13 14:48:49.411360 Completed calc_outdegree_elite in  0.004000186920166016
# 2023-09-13 14:48:49.411730 Completed preprocess_snapshot in  0.02110886573791504
# Graph name without extension: /data-restricted/home/cheick_ba/data_on_nas/archived/triadi_osnem/TemporalTriadDelay/demofiles/triadic_data/karate_2023-09-13 14-48-49/karate_main//karate_main_2017-11-28 00:00:00/karate_main_2017-11-28 00:00:00
# Reading graph: /data-restricted/home/cheick_ba/data_on_nas/archived/triadi_osnem/TemporalTriadDelay/demofiles/triadic_data/karate_2023-09-13 14-48-49/karate_main//karate_main_2017-11-28 00:00:00/karate_main_2017-11-28 00:00:00_mapped.pkl
# Converting to Matrix
# Get the new indices
# MB: 0.001255035400390625
# Dropping graph variable
# Saving Matrix
# Saving new indices
# 2023-09-13 14:48:49.452828 Completed new_generate_snapshot in  0.07650470733642578
#
# Starting parallel census function
# Creating: /data-restricted/home/cheick_ba/data_on_nas/archived/triadi_osnem/TemporalTriadDelay/demofiles/triadic_data/karate_2023-09-13 14-48-49/karate_main//karate_main_2017-11-28 00:00:00/karate_main_2017-11-28 00:00:00_census_list
# storage_path: /data-restricted/home/cheick_ba/data_on_nas/archived/triadi_osnem/TemporalTriadDelay/demofiles/triadic_data/karate_2023-09-13 14-48-49/karate_main//karate_main_2017-11-28 00:00:00/karate_main_2017-11-28 00:00:00_triads
# Creating: /data-restricted/home/cheick_ba/data_on_nas/archived/triadi_osnem/TemporalTriadDelay/demofiles/triadic_data/karate_2023-09-13 14-48-49/karate_main//karate_main_2017-11-28 00:00:00/karate_main_2017-11-28 00:00:00_triads
# log_folder_path: /data-restricted/home/cheick_ba/data_on_nas/archived/triadi_osnem/TemporalTriadDelay/demofiles/triadic_data/karate_2023-09-13 14-48-49/karate_main//karate_main_2017-11-28 00:00:00/karate_main_2017-11-28 00:00:00_logs
# Creating: /data-restricted/home/cheick_ba/data_on_nas/archived/triadi_osnem/TemporalTriadDelay/demofiles/triadic_data/karate_2023-09-13 14-48-49/karate_main//karate_main_2017-11-28 00:00:00/karate_main_2017-11-28 00:00:00_logs
# processes 2
# Chunk size 5
# TOTAL CHUNKS ADJUSTED: 7
# 2023-09-13 14:48:49.489301  Starting with #Chunks: 8
#   0%|          | 0/8 [00:00<?, ?it/s]
# 2023-09-13 14:48:49.637390 MAIN: AGGREGATING RESULTS 2023-09-13 14:48:49.637395
# N is : 0
# /data-restricted/home/cheick_ba/data_on_nas/archived/triadi_osnem/TemporalTriadDelay/demofiles/triadic_data/karate_2023-09-13 14-48-49/results.json.gz

# %% [markdown]
# Plots

# %%
for focus in ["closed","open", "evolutions_new"]:

    for k,agg in mega_results.items():
        print(k)
        aggregated = agg["main"]["aggregated_results"]

        if focus == "open":
            cnt = agg_funcs.get_census_open(aggregated)
            plot_open(cnt, k, focus)
            
        if focus == "closed":
            cnt = agg_funcs.get_census_closed(aggregated)

            plot_closed(cnt, k, focus)
            
        if focus == "evolutions_new":
            evolutions = aggregated['evolutions']
            cnt = { (k[0],k[1:]):v for k,v in evolutions.items()}
            cnt = OrderedDict(sorted(cnt.items(), key= lambda v: ( int(v[0][0]),int(v[0][1]))))
            plot_evolutions(cnt, k, focus)
# Out:
# karate
# Creating: ./images
# Folder: ./images already exists, we are going on
#
# Creating: ./images/png
# Folder: ./images/png already exists, we are going on
#
# Creating: ./images/pdf
# Folder: ./images/pdf already exists, we are going on
#
# ./images/png/karate-closed.png - dpi: 300
# ./images/pdf/karate-closed.pdf - dpi: 300
# karate
# Creating: ./images
# Folder: ./images already exists, we are going on
#
# Creating: ./images/png
# Folder: ./images/png already exists, we are going on
#
# Creating: ./images/pdf
# Folder: ./images/pdf already exists, we are going on
#
# ./images/png/karate-open.png - dpi: 300
# ./images/pdf/karate-open.pdf - dpi: 300
# karate
# [('0', '6'), ('0', '10'), ('1', '6'), ('1', '7'), ('1', '9'), ('2', '8'), ('2', '9'), ('2', '11'), ('3', '6'), ('3', '8'), ('4', '9'), ('4', '10'), ('4', '11'), ('5', '11'), ('5', '12')]
# Creating: ./images
# Folder: ./images already exists, we are going on
#
# Creating: ./images/png
# Folder: ./images/png already exists, we are going on
#
# Creating: ./images/pdf
# Folder: ./images/pdf already exists, we are going on
#
# ./images/png/karate-evolutions_new.png - dpi: 300
# ./images/pdf/karate-evolutions_new.pdf - dpi: 300

# %% [markdown]
# # Run other delay measures

# %%
import sys
import os

try:
    # from tqdm import tqdm
    #from tqdm.notebook import tqdm as tqdm
    from tqdm.auto import tqdm
except ImportError:
    def tqdm(iterator, *args, **kwargs):
        return iterator

import networkx as nx
def get_early_times_for_delay(triangle, ordered_triad, edges_by_time, timestamp_key = "t"):

    a,b,c = ordered_triad
    t_ac = triangle.get_edge_data(a, c, default={timestamp_key:'9999-12-31 23:59:59'})[timestamp_key] # if edge does not exist, return a "infinite date"
    t_ca = triangle.get_edge_data(c, a, default={timestamp_key:'9999-12-31 23:59:59'})[timestamp_key]
    
    birth_ac =  min(t_ac, t_ca ) # either both edges exist and it's a real min(), or only one exists, then i will for sure get it.
    
    early_closing_time = min(t_ac, t_ca )
    
    t_ab = triangle.get_edge_data(a, b, default={timestamp_key:'9999-12-31 23:59:59'})[timestamp_key]
    t_ba = triangle.get_edge_data(b, a, default={timestamp_key:'9999-12-31 23:59:59'})[timestamp_key]
    
    birth_ab = min(t_ab,t_ba)
    
    t_bc = triangle.get_edge_data(b, c, default={timestamp_key:'9999-12-31 23:59:59'})[timestamp_key]
    t_cb = triangle.get_edge_data(c, b, default={timestamp_key:'9999-12-31 23:59:59'})[timestamp_key]
    
    birth_bc = min(t_bc,t_cb)
    
    early_opening_time = max(birth_ab, birth_bc)
   
    return early_opening_time, early_closing_time

# %%
def compute_triadic_closure_delays(save_name, result_path):
    
    from datetime import datetime

    import pandas as pd

    from collections import defaultdict
    
    k = save_name
    fname = result_path

    print(k)
    census = defaultdict(int)  
    triadic_closure_delays_days = defaultdict(int)
    time_closure = defaultdict(int)
    how_many_instant = 0

    agg = enum_commons.load_census_results(SNAP_SETTINGS_PATH=fname)
    total = sum([v for k,v in agg["census"].items() if directed_census_utils.mapping_census_to_baseline[k] in [6,7,8,9,10,11,12] ])

    # for triangle in tqdm(get_stored_triads_debug(fname),total=total ):
    for triangle in tqdm(enum_commons.get_stored_triads(fname),total=total ):
        # triangle is a nx graph , subgraph from the snapshot
        # here i show example of triadic census, we can do what we want here
        #tt = directed_census_utils.get_tricode_name(triangle)#.get_triad_type(triangle, v,u,w)
        # census[tt] +=1 

        res, edges_by_time = directed_census_utils.define_triad_order_new_timestamp_key(triangle, timestamp_key ='timestamp')
        t0,t1 = get_early_times_for_delay(triangle, res["ordered_triad"], edges_by_time, timestamp_key="timestamp")

        time_closure[t1]+=1

        delta = pd.Timestamp(t1) - pd.Timestamp(t0) #datetime.strptime(day1, '%Y-%m-%d')  - datetime.strptime(day0, '%Y-%m-%d')
        delta_days = delta.days
        triadic_closure_delays_days[delta_days] +=1

        if delta.total_seconds() == 0:
            how_many_instant += 1

        #break
    #census

    #how_many_instant
    triadic_closure_delays_days = dict(sorted(triadic_closure_delays_days.items()))
    time_closure = dict(sorted(time_closure.items()))

    # get closures per day because currently is closures per timestamp
    day_closure= defaultdict(int)
    
    for d,v in time_closure.items():
        day_closure[d[:10]] += v
    
    infos_delay = {
        "how_many_instant":how_many_instant, 
        "triadic_closure_delays_days":triadic_closure_delays_days,
        "time_closure":time_closure,
        "day_closure": day_closure
    }

    import pickle
    with open(f"demofiles/triadic_data_delays/{k}.pkl","wb+") as f:
        pickle.dump(infos_delay,f)
        
    return infos_delay

# %%
info_delays_all = {}

for selected_dataset in datasets:
    
    result_path = mega_results[selected_dataset]["main"]["result_path"]
    
    infos_delay = compute_triadic_closure_delays(save_name, result_path)
    
    info_delays_all[selected_dataset] = infos_delay
# Out:
# karate
#   0%|          | 0/45 [00:00<?, ?it/s]

# %% [raw]
# info_delays_all = {}
# datasets = ["karate"]#"osf"
# for k in datasets:
#     with open(f"demofiles/triadic_data_delays/{k}.pkl","rb") as f:
#         info_delays_all[k] = pickle.load(f)

# %%
#increase font size of all elements
sns.set(font_scale=1.2)
sns.set_style("whitegrid")

# %%
focus="triads-delay"
for k in info_delays_all:
    print(k)
    selected = info_delays_all[k] 
    triadic_closure_delays_days = selected["triadic_closure_delays_days"]

    x = [ pair[0] for pair in triadic_closure_delays_days.items()]
    y = [ pair[1] for pair in triadic_closure_delays_days.items()]
    y = np.cumsum([ pair[1] for pair in sorted(triadic_closure_delays_days.items())])/sum([ pair[1] for pair in triadic_closure_delays_days.items()])

    plt.figure(figsize=(6,4))
    plt.plot(x,y,color=None, lw = 5)

    # line_dates=[4,8,12,20,30]
    # for l in line_dates:
    #     plt.axvline(l,color='r',alpha=0.5)
    
    # plt.xlim((0.1,None))
    plt.ylim((0,1))
    plt.xscale("log")
    plt.grid()
    
    # ax = plt.gca()
    # #ax.get_xaxis().set_minor_locator(mpl.ticker.AutoMinorLocator())
    # ax.get_yaxis().set_minor_locator(mpl.ticker.AutoMinorLocator())
    # ax.grid(visible=True, which='major', color='darkgrey', linewidth=1.0)
    # ax.grid(visible=True, which='minor', color='darkgrey', linewidth=0.5)
    
    save_current_image_in_folder(fname=f"{k}-{focus}", folder_path=".")
    
    plt.show()
# Out:
# karate
# Creating: ./images
# Folder: ./images already exists, we are going on
#
# Creating: ./images/png
# Folder: ./images/png already exists, we are going on
#
# Creating: ./images/pdf
# Folder: ./images/pdf already exists, we are going on
#
# ./images/png/karate-triads-delay.png - dpi: 300
# ./images/pdf/karate-triads-delay.pdf - dpi: 300

# %% [markdown]
# Links per day

# %%
def compute_links_per_day(result_path, timestamp_key="timestamp"):
    
    
    G = enum_commons.get_original_snapshot(result_path)
    link_ts = [ e[2][timestamp_key][:10] for e in G.edges(data=True)]
        
    print(len(link_ts), len(set(link_ts))) # corresponds to every ts of the projected graph
    
    links_per_day = OrderedDict( sorted(Counter(link_ts).items() ))
        
    return links_per_day

# %%
from collections import Counter, defaultdict, OrderedDict

links_per_day_all = {}

for k,v in datasets.items():
    # save_name = k
    """
    dataset = v
    
    PROCESSED_DATA_FILEPATH = datasets = v #"/data-restricted/home/cheick_ba/safe_datasets_on_nas/safe_datasets/processed/imc22/preprocessed/OSF/OSF.csv.gz"

    transactions = glib_storage.load_transactions_dataframe(PROCESSED_DATA_FILEPATH)
    
    link_timeday = list(transactions.groupby(['from', 'to'])['timestamp'].min().astype(str))#[0][:10]
    
    link_ts = [ t[:10] for t in link_timeday ]
    
    print(len(link_ts), len(set(link_ts))) # corresponds to every ts of the projected graph
    
    links_per_day = OrderedDict( sorted(Counter(link_ts).items() ))
    
    links_per_day_all[k] = links_per_day
    #break
    """
    selected_dataset = k
    
    result_path = mega_results[selected_dataset]["main"]["result_path"]
    
    links_per_day_all[k] = compute_links_per_day(result_path, timestamp_key="timestamp")
# Out:
# 147 28

# %%
import numpy as np
from scipy.ndimage.filters import uniform_filter1d
# Out:
# /tmp/ipykernel_1719424/3309814372.py:2: DeprecationWarning: Please use `uniform_filter1d` from the `scipy.ndimage` namespace, the `scipy.ndimage.filters` namespace is deprecated.
#   from scipy.ndimage.filters import uniform_filter1d

# %%
running_avg_window = 7

# %%
focus = "ratio"
for k in info_delays_all:
    print(k)
    
    interval = 90
    #plt.figure(figsize=(6,4))
    fig, ax = plt.subplots(figsize=(8,5))      

    # Closures per day
    selected = info_delays_all[k]  
    day_closure = selected["day_closure"]
    x2 = [ datetime.strptime(pair[0], '%Y-%m-%d') for pair in day_closure.items()]
    y2 = [ pair[1] for pair in day_closure.items()]
    
    y2 = uniform_filter1d(y2, size = running_avg_window)
    
    plt.plot(x2,y2,alpha=0.9, color="tab:blue", label="Triads", zorder=1)
    # plt.fill_between(x2, y2, alpha=0.4, color="tab:blue", zorder=1)

    # Links per day
    links_per_day = links_per_day_all[k]
    x = [ datetime.strptime(pair[0], '%Y-%m-%d') for pair in links_per_day.items()]
    y = [ pair[1] for pair in links_per_day.items()]
    y = uniform_filter1d(y, size = running_avg_window)
    
    plt.plot(x,y, alpha=0.9, color="tab:orange", label="Links", zorder=2)
    # plt.fill_between(x, y, alpha=0.4, color="tab:orange", zorder=2)
    
    
    formatter = DateFormatter('%b %Y')
    plt.gcf().axes[0].xaxis.set_major_formatter(formatter)
    plt.gcf().axes[0].xaxis.set_major_locator(DayLocator(interval=interval))
    #plt.gcf().axes[0].xaxis.grid(True, which="minor")
    #plt.gcf().autofmt_xdate()
    plt.ylabel('Links and triads')

    plt.xticks(rotation='-25', fontsize = 10)
    plt.yscale("log")
    # plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0), useMathText=True)

    plt.legend(loc = "upper left")
    # Ratio 
    
    ax2 = ax.twinx()  # instantiate a second axes that shares the same x-axis
    ax2.set_ylabel('Triads/Links')#, color=color)  # we already handled the x-label with ax1
    
    # Note: triangles / links. There cannot be a closure without links. We could have link not leading to closures, but it's unlikely.
    # So we should have that len(triangles_per_day) <= len(links_per_day)
    x3 = []
    y3 = []
    for d,v in links_per_day.items():
        x3.append(d)
        if d in day_closure:
            n = day_closure[d]
        else:
            n = 0
        ratio = n/v
        y3.append(ratio)
    x3 = [ datetime.strptime(d, '%Y-%m-%d') for d in x3]
    y3 = uniform_filter1d(y3, size = running_avg_window)
    
    plt.plot(x3,y3,color="firebrick", label="Ratio", lw=2)
    
    plt.ylim((0,None))
    # plt.grid()
    plt.legend(loc="upper right")
    # ax = plt.gca()
    # #ax.get_xaxis().set_minor_locator(mpl.ticker.AutoMinorLocator())
    # ax.get_yaxis().set_minor_locator(mpl.ticker.AutoMinorLocator())
    # ax.grid(visible=True, which='major', color='darkgrey', linewidth=1.0)
    # ax.grid(visible=True, which='minor', color='darkgrey', linewidth=0.5)
    
    save_current_image_in_folder(fname=f"{k}-{focus}", folder_path=".")

    plt.show()
# Out:
# karate
# Creating: ./images
# Folder: ./images already exists, we are going on
#
# Creating: ./images/png
# Folder: ./images/png already exists, we are going on
#
# Creating: ./images/pdf
# Folder: ./images/pdf already exists, we are going on
#
# ./images/png/karate-ratio.png - dpi: 300
# ./images/pdf/karate-ratio.pdf - dpi: 300

# %% [raw]
# ! zip -r images.zip images/
